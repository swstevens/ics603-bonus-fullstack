# %% [markdown]
# # Test Classifier
# Testing the reflection topic classifier

# %%
from dotenv import load_dotenv
import os
load_dotenv()

# %%
from classifier import classify_reflection_topics

# %%
await classify_reflection_topics(
    title="Learning new things", 
    text="I find it so fulfilling to learn new things. I wish I could spend my days just learning new things",
    existing_topics=["learning", "growth", "surfing", "parenting", "cooking"]
)
